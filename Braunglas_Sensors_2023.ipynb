# %%
#%pip install pandas

# %%
# Import data for Braunglas:
import pandas as pd
df = pd.read_csv("braunglas.csv", sep = ";")
df
# Out:
#                       measured_at                                   data  \
# 0       2020-02-24T09:52:09+01:00                             {"foo": 3}
# 1       2020-02-24T09:42:33+01:00                             {"foo": 3}
# 2       2020-02-24T09:18:36+01:00                             {"foo": 3}
# 3       2020-02-24T09:12:33+01:00                             {"foo": 3}
# 4       2020-02-24T08:48:36+01:00                             {"foo": 3}
# ...                           ...                                    ...
# 620468  2023-09-10T12:24:00+02:00  {"type": "reading", "distance": 1096}
# 620469  2023-09-10T12:18:52+02:00   {"type": "reading", "distance": 924}
# 620470  2023-09-10T11:40:40+02:00  {"type": "reading", "distance": 1182}
# 620471  2023-09-10T11:17:42+02:00  {"type": "reading", "distance": 1376}
# 620472  2023-09-10T11:11:41+02:00   {"type": "reading", "distance": 817}
#
#                                    device_id           name  \
# 0       4f48bac6-9d0e-4879-93ad-5bf39b4c5915  107109 | 67EF
# 1       1e8d1b09-d186-495e-bd1f-cb06afdd5b21  107054 | 2AE2
# 2       473a8148-3001-42ec-946e-55d479bfc9c4  107053 | 667E
# 3       1e8d1b09-d186-495e-bd1f-cb06afdd5b21  107054 | 2AE2
# 4       473a8148-3001-42ec-946e-55d479bfc9c4  107053 | 667E
# ...                                      ...            ...
# 620468  473a8148-3001-42ec-946e-55d479bfc9c4  107053 | 667E
# 620469  624e62e7-2b0b-43dc-a992-77ab95adbbb8  107026 | 67BE
# 620470  f5afab11-faaa-4bf1-8d4f-d76bdf5381f4  107043 | 8300
# 620471  4f48bac6-9d0e-4879-93ad-5bf39b4c5915  107109 | 67EF
# 620472  fa37f819-027b-4f6e-8e7d-1c80488f036f  107044 | 63DB
#
#                                           id  \
# 0       526a0ccc-00ab-4a7f-ac15-ee173dac7360
# 1       1e042495-21da-40b4-87cf-5fccba5eb770
# 2       67118b4f-5eb2-4f1d-b885-f0f367233e32
# 3       a50f08d1-1667-4cdd-9406-4ae70937dfcc
# 4       4551cb6a-2d4f-4d62-a42e-65306a92c303
# ...                                      ...
# 620468  5e0fd6fc-c36c-42ae-b1c2-b6966c34bb4c
# 620469  5662ac27-7cb9-4f5d-bff6-e80bcbe79f6e
# 620470  33ae084e-743a-4f3e-ae41-78b65aa4baf8
# 620471  e4e22406-1761-4813-b406-ee346a5ca87f
# 620472  16ec1ac3-0004-42d1-8751-2be826339117
#
#                                                  location  data_distance  \
# 0       {"coordinates": [9.360562526050046, 47.4257577...            NaN
# 1       {"coordinates": [9.34623629581722, 47.41967910...            NaN
# 2       {"coordinates": [9.333639241159204, 47.4079475...            NaN
# 3       {"coordinates": [9.34623629581722, 47.41967910...            NaN
# 4       {"coordinates": [9.333639241159204, 47.4079475...            NaN
# ...                                                   ...            ...
# 620468  {"coordinates": [9.333639241159204, 47.4079475...         1096.0
# 620469  {"coordinates": [9.335980774191682, 47.4120650...          924.0
# 620470  {"coordinates": [9.39310213730485, 47.42544544...         1182.0
# 620471  {"coordinates": [9.360562526050046, 47.4257577...         1376.0
# 620472  {"coordinates": [9.406655639484512, 47.4392055...          817.0
#
#                                  geo_point_2d
# 0        47.42575774663251, 9.360562526050046
# 1        47.419679102687155, 9.34623629581722
# 2        47.40794753166517, 9.333639241159204
# 3        47.419679102687155, 9.34623629581722
# 4        47.40794753166517, 9.333639241159204
# ...                                       ...
# 620468   47.40794753166517, 9.333639241159204
# 620469  47.412065012904804, 9.335980774191682
# 620470    47.42544544302447, 9.39310213730485
# 620471   47.42575774663251, 9.360562526050046
# 620472   47.43920554529265, 9.406655639484512
#
# [620473 rows x 8 columns]

# %%
df = pd.read_csv("braunglas.csv", sep = ";")

# Get all rows with nan data distance values:
nan_distance = df.loc[df["data_distance"].isna()].copy()

# Compile Device ids in a list:
nan_device_id_list = []
for i in nan_distance["device_id"].unique():
    nan_device_id_list.append(i)

nan_device_id_list
# Out:
# ['4f48bac6-9d0e-4879-93ad-5bf39b4c5915',
#  '1e8d1b09-d186-495e-bd1f-cb06afdd5b21',
#  '473a8148-3001-42ec-946e-55d479bfc9c4',
#  '75ba05c7-3c77-4160-a72d-8dc15efee2c5',
#  'c737f0e5-1838-46ea-8806-89935bd3a560',
#  'ba09e800-34d1-4d0d-8b2b-361aabe93648',
#  'd8a3a3ca-39d7-46a2-9c50-0b5bc1717979',
#  '04c14b60-34a4-40ab-aae2-bf4d616eb0d6',
#  '624e62e7-2b0b-43dc-a992-77ab95adbbb8',
#  '7cfecc22-d53c-45b4-8eb2-cb8219ca531e',
#  'fa37f819-027b-4f6e-8e7d-1c80488f036f',
#  'bd1f5d39-0361-4717-9054-845ac2fa33bd',
#  'f5afab11-faaa-4bf1-8d4f-d76bdf5381f4',
#  '3dd2b101-9f8d-41fa-9dc3-823729aefabb',
#  'ae87483e-d1ed-4169-a05b-5f53d38c7185',
#  '72b408a3-5924-4c60-8f7f-ff534de140fb']

# %%
# Get rid of all nans
df = df.dropna()
df
# Out:
#                       measured_at                                   data  \
# 25      2020-02-24T01:36:32+01:00   {"type": "reading", "distance": 688}
# 41      2020-02-23T21:36:33+01:00   {"type": "reading", "distance": 688}
# 63      2020-02-23T14:36:35+01:00   {"type": "reading", "distance": 688}
# 72      2020-02-23T11:06:36+01:00   {"type": "reading", "distance": 688}
# 74      2020-02-23T09:36:36+01:00   {"type": "reading", "distance": 688}
# ...                           ...                                    ...
# 620468  2023-09-10T12:24:00+02:00  {"type": "reading", "distance": 1096}
# 620469  2023-09-10T12:18:52+02:00   {"type": "reading", "distance": 924}
# 620470  2023-09-10T11:40:40+02:00  {"type": "reading", "distance": 1182}
# 620471  2023-09-10T11:17:42+02:00  {"type": "reading", "distance": 1376}
# 620472  2023-09-10T11:11:41+02:00   {"type": "reading", "distance": 817}
#
#                                    device_id           name  \
# 25      624e62e7-2b0b-43dc-a992-77ab95adbbb8  107026 | 67BE
# 41      624e62e7-2b0b-43dc-a992-77ab95adbbb8  107026 | 67BE
# 63      624e62e7-2b0b-43dc-a992-77ab95adbbb8  107026 | 67BE
# 72      624e62e7-2b0b-43dc-a992-77ab95adbbb8  107026 | 67BE
# 74      624e62e7-2b0b-43dc-a992-77ab95adbbb8  107026 | 67BE
# ...                                      ...            ...
# 620468  473a8148-3001-42ec-946e-55d479bfc9c4  107053 | 667E
# 620469  624e62e7-2b0b-43dc-a992-77ab95adbbb8  107026 | 67BE
# 620470  f5afab11-faaa-4bf1-8d4f-d76bdf5381f4  107043 | 8300
# 620471  4f48bac6-9d0e-4879-93ad-5bf39b4c5915  107109 | 67EF
# 620472  fa37f819-027b-4f6e-8e7d-1c80488f036f  107044 | 63DB
#
#                                           id  \
# 25      84d62d29-5900-44fa-b814-2441b3b8a003
# 41      82a29a3f-1915-41b6-a160-f970e5f21a30
# 63      5944d283-bc2e-497e-9327-27ce3a6be436
# 72      7b10d463-0454-43cc-b74b-5f2239c8f961
# 74      1e19843c-07fe-44c9-9f1c-182cb1138b85
# ...                                      ...
# 620468  5e0fd6fc-c36c-42ae-b1c2-b6966c34bb4c
# 620469  5662ac27-7cb9-4f5d-bff6-e80bcbe79f6e
# 620470  33ae084e-743a-4f3e-ae41-78b65aa4baf8
# 620471  e4e22406-1761-4813-b406-ee346a5ca87f
# 620472  16ec1ac3-0004-42d1-8751-2be826339117
#
#                                                  location  data_distance  \
# 25      {"coordinates": [9.335980774191682, 47.4120650...          688.0
# 41      {"coordinates": [9.335980774191682, 47.4120650...          688.0
# 63      {"coordinates": [9.335980774191682, 47.4120650...          688.0
# 72      {"coordinates": [9.335980774191682, 47.4120650...          688.0
# 74      {"coordinates": [9.335980774191682, 47.4120650...          688.0
# ...                                                   ...            ...
# 620468  {"coordinates": [9.333639241159204, 47.4079475...         1096.0
# 620469  {"coordinates": [9.335980774191682, 47.4120650...          924.0
# 620470  {"coordinates": [9.39310213730485, 47.42544544...         1182.0
# 620471  {"coordinates": [9.360562526050046, 47.4257577...         1376.0
# 620472  {"coordinates": [9.406655639484512, 47.4392055...          817.0
#
#                                  geo_point_2d
# 25      47.412065012904804, 9.335980774191682
# 41      47.412065012904804, 9.335980774191682
# 63      47.412065012904804, 9.335980774191682
# 72      47.412065012904804, 9.335980774191682
# 74      47.412065012904804, 9.335980774191682
# ...                                       ...
# 620468   47.40794753166517, 9.333639241159204
# 620469  47.412065012904804, 9.335980774191682
# 620470    47.42544544302447, 9.39310213730485
# 620471   47.42575774663251, 9.360562526050046
# 620472   47.43920554529265, 9.406655639484512
#
# [553834 rows x 8 columns]

# %%
# Compiling list of all ids without nan values present in their distance:
df["device_id"].value_counts()

non_nan_device_id_list = []
for i in df["device_id"].unique():
    non_nan_device_id_list.append(i)

non_nan_device_id_list
# Out:
# ['624e62e7-2b0b-43dc-a992-77ab95adbbb8',
#  'ae87483e-d1ed-4169-a05b-5f53d38c7185',
#  '4f48bac6-9d0e-4879-93ad-5bf39b4c5915',
#  '3dd2b101-9f8d-41fa-9dc3-823729aefabb',
#  'bd1f5d39-0361-4717-9054-845ac2fa33bd',
#  '473a8148-3001-42ec-946e-55d479bfc9c4',
#  '7cfecc22-d53c-45b4-8eb2-cb8219ca531e',
#  'd8a3a3ca-39d7-46a2-9c50-0b5bc1717979',
#  'c737f0e5-1838-46ea-8806-89935bd3a560',
#  '1e8d1b09-d186-495e-bd1f-cb06afdd5b21',
#  '72b408a3-5924-4c60-8f7f-ff534de140fb',
#  'fa37f819-027b-4f6e-8e7d-1c80488f036f',
#  'f5afab11-faaa-4bf1-8d4f-d76bdf5381f4',
#  '04c14b60-34a4-40ab-aae2-bf4d616eb0d6',
#  '75ba05c7-3c77-4160-a72d-8dc15efee2c5']

# %%
# Copying list we created above into this code part:
nan_device_id_list = ['4f48bac6-9d0e-4879-93ad-5bf39b4c5915',
 '1e8d1b09-d186-495e-bd1f-cb06afdd5b21',
 '473a8148-3001-42ec-946e-55d479bfc9c4',
 '75ba05c7-3c77-4160-a72d-8dc15efee2c5',
 'c737f0e5-1838-46ea-8806-89935bd3a560',
 'ba09e800-34d1-4d0d-8b2b-361aabe93648',
 'd8a3a3ca-39d7-46a2-9c50-0b5bc1717979',
 '04c14b60-34a4-40ab-aae2-bf4d616eb0d6',
 '624e62e7-2b0b-43dc-a992-77ab95adbbb8',
 '7cfecc22-d53c-45b4-8eb2-cb8219ca531e',
 'fa37f819-027b-4f6e-8e7d-1c80488f036f',
 'bd1f5d39-0361-4717-9054-845ac2fa33bd',
 'f5afab11-faaa-4bf1-8d4f-d76bdf5381f4',
 '3dd2b101-9f8d-41fa-9dc3-823729aefabb',
 'ae87483e-d1ed-4169-a05b-5f53d38c7185',
 '72b408a3-5924-4c60-8f7f-ff534de140fb']

# %%
# Convert lists to sets for easier set operations:
set1 = set(non_nan_device_id_list)
set2 = set(nan_device_id_list)

# List for common elements
common_elements = list(set1.intersection(set2))

# List for elements only in the first list:
only_in_non_nan = list(set1.difference(set2))

# List for elements only in the second list:
only_in_nan = list(set2.difference(set1))

# Print results:
print("Common elements:", common_elements)
print("Elements only in the non_nan list:", only_in_non_nan)
print("Elements only in the nan list:", only_in_nan)
# Out:
# Common elements: ['4f48bac6-9d0e-4879-93ad-5bf39b4c5915', '624e62e7-2b0b-43dc-a992-77ab95adbbb8', '473a8148-3001-42ec-946e-55d479bfc9c4', 'bd1f5d39-0361-4717-9054-845ac2fa33bd', 'd8a3a3ca-39d7-46a2-9c50-0b5bc1717979', 'c737f0e5-1838-46ea-8806-89935bd3a560', '75ba05c7-3c77-4160-a72d-8dc15efee2c5', '3dd2b101-9f8d-41fa-9dc3-823729aefabb', '72b408a3-5924-4c60-8f7f-ff534de140fb', 'f5afab11-faaa-4bf1-8d4f-d76bdf5381f4', '7cfecc22-d53c-45b4-8eb2-cb8219ca531e', 'fa37f819-027b-4f6e-8e7d-1c80488f036f', '04c14b60-34a4-40ab-aae2-bf4d616eb0d6', 'ae87483e-d1ed-4169-a05b-5f53d38c7185', '1e8d1b09-d186-495e-bd1f-cb06afdd5b21']
# Elements only in the non_nan list: []
# Elements only in the nan list: ['ba09e800-34d1-4d0d-8b2b-361aabe93648']

# %%
import pandas as pd

# Calculation of nan % for all ids:
df = pd.read_csv("braunglas.csv", sep = ";")

# Get all rows with nan data distance values:
nan_distance = df.loc[df["data_distance"].isna()].copy()

# Compile Device ids in a list:
nan_device_id_list = []
for i in nan_distance["device_id"].unique():
    nan_device_id_list.append(i)

nan_device_id_list

# Create a list of device_ids:
device_ids = nan_device_id_list  # Replace with your actual device_ids


# Step 3: Loop through each device_id
for device_id in device_ids:
    # Filter the DataFrame for the current device_id
    device_df = df.loc[df['device_id'] == device_id]

    # Calculate the number of rows before dropping NaN values
    rows_before = len(device_df)

    # Calculate the number of rows after dropping NaN values
    rows_after = len(device_df.dropna())

    # Step 4: Calculate the percentage of NaN values
    percentage_nan = ((rows_before - rows_after) / rows_before) * 100

    # Print results:
    print(f"For device_id {device_id}:")
    print(f"  Rows before dropping NaN values: {rows_before}")
    print(f"  Rows after dropping NaN values: {rows_after}")
    print(f"  Percentage of NaN values: {percentage_nan:.2f}%")
    print("")
# Out:
# For device_id 4f48bac6-9d0e-4879-93ad-5bf39b4c5915:
#   Rows before dropping NaN values: 64550
#   Rows after dropping NaN values: 55126
#   Percentage of NaN values: 14.60%
#
# For device_id 1e8d1b09-d186-495e-bd1f-cb06afdd5b21:
#   Rows before dropping NaN values: 38559
#   Rows after dropping NaN values: 29792
#   Percentage of NaN values: 22.74%
#
# For device_id 473a8148-3001-42ec-946e-55d479bfc9c4:
#   Rows before dropping NaN values: 66707
#   Rows after dropping NaN values: 57300
#   Percentage of NaN values: 14.10%
#
# For device_id 75ba05c7-3c77-4160-a72d-8dc15efee2c5:
#   Rows before dropping NaN values: 22195
#   Rows after dropping NaN values: 14708
#   Percentage of NaN values: 33.73%
#
# For device_id c737f0e5-1838-46ea-8806-89935bd3a560:
#   Rows before dropping NaN values: 48674
#   Rows after dropping NaN values: 39915
#   Percentage of NaN values: 18.00%
#
# For device_id ba09e800-34d1-4d0d-8b2b-361aabe93648:
#   Rows before dropping NaN values: 3705
#   Rows after dropping NaN values: 0
#   Percentage of NaN values: 100.00%
#
# For device_id d8a3a3ca-39d7-46a2-9c50-0b5bc1717979:
#   Rows before dropping NaN values: 20670
#   Rows after dropping NaN values: 12330
#   Percentage of NaN values: 40.35%
#
# For device_id 04c14b60-34a4-40ab-aae2-bf4d616eb0d6:
#   Rows before dropping NaN values: 7285
#   Rows after dropping NaN values: 4558
#   Percentage of NaN values: 37.43%
#
# For device_id 624e62e7-2b0b-43dc-a992-77ab95adbbb8:
#   Rows before dropping NaN values: 64598
#   Rows after dropping NaN values: 63146
#   Percentage of NaN values: 2.25%
#
# For device_id 7cfecc22-d53c-45b4-8eb2-cb8219ca531e:
#   Rows before dropping NaN values: 2514
#   Rows after dropping NaN values: 2212
#   Percentage of NaN values: 12.01%
#
# For device_id fa37f819-027b-4f6e-8e7d-1c80488f036f:
#   Rows before dropping NaN values: 59645
#   Rows after dropping NaN values: 58329
#   Percentage of NaN values: 2.21%
#
# For device_id bd1f5d39-0361-4717-9054-845ac2fa33bd:
#   Rows before dropping NaN values: 54184
#   Rows after dropping NaN values: 52987
#   Percentage of NaN values: 2.21%
#
# For device_id f5afab11-faaa-4bf1-8d4f-d76bdf5381f4:
#   Rows before dropping NaN values: 59410
#   Rows after dropping NaN values: 58048
#   Percentage of NaN values: 2.29%
#
# For device_id 3dd2b101-9f8d-41fa-9dc3-823729aefabb:
#   Rows before dropping NaN values: 21012
#   Rows after dropping NaN values: 20547
#   Percentage of NaN values: 2.21%
#
# For device_id ae87483e-d1ed-4169-a05b-5f53d38c7185:
#   Rows before dropping NaN values: 50779
#   Rows after dropping NaN values: 49648
#   Percentage of NaN values: 2.23%
#
# For device_id 72b408a3-5924-4c60-8f7f-ff534de140fb:
#   Rows before dropping NaN values: 35986
#   Rows after dropping NaN values: 35188
#   Percentage of NaN values: 2.22%
